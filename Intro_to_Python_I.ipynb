# %% [markdown]
# # **Lab 1 - Introduction to Python programming I**

# %% [markdown]
# Enter your code in the spaces provided.  Do not change any of the variable names or function names that are already provided for you.  In places where we specify the name of the return value, make sure that your code produces the a value with the correct name.

# %%
# Do not edit this cell.

LabID="Lab1"

# %% [markdown]
# **Enter your name, section number, and BYU NetID**

# %%
# Enter your first and last names in between the quotation marks.

first_name="Jared"

last_name="Wright"

# Enter your section number in between the quotation marks. 

section_number="2"  

# Enter your BYU NetID in between the quotation marks.  NOT YOUR BYU ID NUMBER!

BYUNetID="jaredmw2"

# %% [markdown]
# **Problem 1**

# %%
my_first_var=(118+11*2)/(9-2) # Replace the value of 0 with the required expression from Problem 1.

# %% [markdown]
# **Problem 2**

# %%
def arithmetic2(i):
  return (i+2)*3-5# Put your return value here.  Your shouldn't need to add any more lines of code to this function.

# %% [markdown]
# **Problem 3**

# %%
def triple(y):
  return 3*y # Put your return value here.

# %%
def avg(x,y):
  return (x+y)/2# Put your return value here.

# %%
def combine(x,y):
  avg(triple(y),x) # Put your code here.  Remember that this function should call both of the functions triple(y) and avg(x,y) from above.
  return # Put your return value here.

# %% [markdown]
# **Problem 4**

# %%
def first(c):
  first_element=c[0]
  # Put your code here, which should correctly redefine the value of the variable first_element.  We've already set up the return statement for you.
  return first_element

# %%
def first_last(c):
  first_element=c[0]
  last_element=c[-1]
  # Put your code here, which should correctly redefine the values of the variables first_element and last_element.  We've already set up the return statement for you.
  return first_element,last_element

# %%
def middle(c):
  middle_list=c[1:-1]
  # Put your code here, which should correctly redefine the value of the list middle_list.  We've already set up the return statement for you.
  return middle_list

# %% [markdown]
# **Problem 5**

# %%
def swap(c):
  original_list=list(c) # This creates a copy of the list c, which is called original_list.  Your function should work with this list instead of the list c which is passed to the function.
  swapped_list=original_list.copy()
  swapped_list[0]=original_list[-1]
  swapped_list[-1]=original_list[0]
  # Put your code here, which should correctly redefine the value of the list swapped_list.  We've already set up the return statement for you.
  return swapped_list

# %% [markdown]
# **Problem 6**

# %%
def absolute_value(x):
  if x<0:
    abs_val=-x
  else:
    abs_val=x
  # Put your code here, which should correctly redefine the value of the variable abs_value.  We've already set up the return statement for you.
  return abs_val

# %% [markdown]
# **Problem 7**

# %%
def indicator(lower,upper,n):
  ind_val=(lower <= n <= upper)
  # Put your code here, which should correctly redefine the value of the variable ind_val.  We've already set up the return statement for you.
  return ind_val

# %% [markdown]
# **Problem 8**

# %%
def trunc_max(x,y):
  tm_val=max(0,x,y)
  # Put your code here, which should correctly redefine the value of the variable tm_val.  We've already set up the return statement for you.
  return tm_val

# %% [markdown]
# **STOP!  BEFORE YOU SUBMIT THIS LAB:**  Go to the "Runtime" menu at the top of this page, and select "Restart and run all".  If any of the cells produce error messages, you will either need to fix the error(s) or delete the code that is causing the error(s).  Then use "Restart and run all" again to see if there are any new errors.  Repeat this until no new error messages show up.

# %% [markdown]
# **You are not ready to submit until you are able to select "Restart and run all" without any new error messages showing up.  Your code will not be able to be graded if there are any error messages.**
