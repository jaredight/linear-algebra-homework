# %% [markdown]
# #**Lab 9 - Iterative eigenvalues and Markov chains**

# %% [markdown]
# Enter your code in the spaces provided. Do not change any of the variable names or function names that are already provided for you. In places where we specify the name of the return value, make sure that your code produces the a value with the correct name.

# %%
# Do not edit this cell.

LabID="Lab9"

# %% [markdown]
# **Enter your name, section number, and BYU NetID**

# %%
# Enter your first and last names in between the quotation marks.

first_name="Jared"

last_name="Wright"

# Enter your section number in between the quotation marks. 

section_number="2"  

# Enter your BYU NetID in between the quotation marks.  NOT YOUR BYU ID NUMBER!

BYUNetID="jaredmw2"

# %% [markdown]
# **Import NumPy**

# %%
import numpy as np

# %% [markdown]
# **Problem 1**

# %%
# This function approximates the dominant eigenvector of our matrix A.

def evect_approx1(x_0,k):
  x_vect=x_0
  for j in range(1,k+1):
    x_vect=np.dot(np.array([[1,1],[2,0]]),x_vect)
  return x_vect

#evect_approx1(np.array([1,9]),10)

# %% [markdown]
# **Problem 2**

# %%
# This function approximates the dominant eigenvalue of our matrix A.

def eval_approx1(x_0,k):
  x_k=evect_approx1(x_0,k)
  x_k1=evect_approx1(x_0,k+1)
  lambda_1=x_k1[0]/x_k[0]
  # Put your code here, which should redefine the value of lambda_1 as described in Problem 2. Do not change anything in the function definition or return statement lines.
  return lambda_1
#eval_approx1(np.array([1,9]),10)

# %% [markdown]
# **Problem 3**

# %%
# This function approximates the dominant eigenvalue and eigenvector of our matrix A using the normalized iterative process.

def norm_evect_approx1(x_0,k):
  x_vect=x_0
  lambda_1=eval_approx1(x_vect,k)
  for i in range(1,k+1):
    x_vect=evect_approx1(x_vect,1)
    norm = np.linalg.norm(x_vect)
    x_vect = x_vect/norm
  return x_vect,lambda_1
#norm_evect_approx1(np.array([1,9]),10)

# %% [markdown]
# **Problem 4**

# %%
# This function approximates the dominant eigenvalue and eigenvector of an arbitrary matrix using the process described in Problem 4.

def norm_approx_gen(M,x_0,k):
  x_vect=x_0
  for i in range(1,k+1):
    oldx_vect=x_vect
    x_vect=np.dot(M,x_vect)
    lambda_1=x_vect[0]/oldx_vect[0]
    maxval=np.max(np.abs(x_vect))
    x_vect = x_vect/maxval
  # Put your code here, which should redefine the values of lambda_1 and x_vect as described in Problem 4. Do not change anything in the function definition or return statement lines.
  return x_vect,lambda_1

#norm_approx_gen(np.array([[2,4,6],[4,8,0],[1,2,9]]),np.array([1,5,-1]),10)

# %% [markdown]
# **Problem 5**

# %%
# This function approximates the dominant eigenvalue and eigenvector of an arbitrary matrix using the Rayleigh quotiend as described in Problem 5.

def ray_quotient(M,x_0,k):
  x_vect=x_0
  for i in range(1,k+1):
    oldx_vect=x_vect
    x_vect=np.dot(M,x_vect)
    lambda_1=x_vect[0]/oldx_vect[0]
    maxval=np.max(np.abs(x_vect))
    x_vect = x_vect/maxval
  lambda_1 = np.dot(np.dot(M,x_vect),x_vect)/np.dot(x_vect,x_vect)
  # Put your code here, which should redefine the values of lambda_1 and x_vect as described in Problem 5. Do not change anything in the function definition or return statement lines.
  return lambda_1

#ray_quotient(np.array([[2,4,6],[4,8,0],[1,2,9]]),np.array([1,5,-1]),10)

# %% [markdown]
# **Problem 6**

# %%
# Replace all of the 0 values with the vectors requested in Problem 6.

x_vect_3, l_3 = norm_approx_gen(np.array([[3,2,-2],[-1,1,4],[3,2,-5]]),np.array([1,1,1]),3)

x_vect_4, l_4 = norm_approx_gen(np.array([[3,2,-2],[-1,1,4],[3,2,-5]]),np.array([1,1,1]),4)

#print(x_vect_3)
#print(x_vect_4)

# %% [markdown]
# **Problem 7**

# %%
# This function returns the number of subscribers to the different streaming services after month k.

def subscriber_vals(x_0,k):
  x_vect=x_0
  for i in range(1,k+1):
    x_vect=np.dot(np.array([[0.7,0.2],[0.3,0.8]]),x_vect)
    
  # Put your code here, which should redefine the values of x_vect as described in Problem 7. Do not change anything in the function definition or return statement lines.
  return x_vect

# %% [markdown]
# **Problem 8**

# %%
# Replace all of the 0 values with the vector requested in Problem 8.

netflix_subs6=subscriber_vals(np.array([0.6,0.4]),6)[0]
#netflix_subs6

# %% [markdown]
# **Problem 9**

# %%
# Replace all of the 0 values with the vectors requested in Problem 9.

trans_matrix=np.transpose(np.array([[.8,.05,.1,0.05],[.5,.2,.1,.2],[.3,.1,.3,.3],[.2,.1,.1,.6]]))

x_vt=np.array([0.5,.2,.3,0])
for i in range(1,100):
  x_vt=np.dot(np.transpose(np.array([[.8,.05,.1,0.05],[.5,.2,.1,.2],[.3,.1,.3,.3],[.2,.1,.1,.6]])),x_vt)
x_vt_sum=np.sum(x_vt)
x_vt_sum
x_vt=x_vt/x_vt_sum

steady_state=x_vt
pond_C=steady_state[2]

# %% [markdown]
# **STOP!  BEFORE YOU SUBMIT THIS LAB:**  Go to the "Runtime" menu at the top of this page, and select "Restart and run all".  If any of the cells produce error messages, you will either need to fix the error(s) or delete the code that is causing the error(s).  Then use "Restart and run all" again to see if there are any new errors.  Repeat this until no new error messages show up.

# %% [markdown]
# **You are not ready to submit until you are able to select "Restart and run all" without any new error messages showing up.  Your code will not be able to be graded if there are any error messages.**
